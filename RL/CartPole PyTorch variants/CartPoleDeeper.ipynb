# %% [markdown]
# Ref:
# <https://jaromiru.com/2016/10/03/lets-make-a-dqn-implementation/>

# %%
import os

import random, numpy, math, gym
from matplotlib import pyplot as plt


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as I

# %%
#-------------------- BRAIN ---------------------------
class DQN(nn.Module):

    def __init__(self, stateCnt, actionCnt):
        super(DQN, self).__init__()
        self.stateCnt = stateCnt
        self.actionCnt = actionCnt
        self.fc1 = nn.Linear(in_features=stateCnt, out_features=64)
        self.fc2 = nn.Linear(in_features=64, out_features=64)
        self.fc_out = nn.Linear(in_features=64, out_features=actionCnt)
        I.kaiming_uniform_(self.fc1.weight)
        I.kaiming_uniform_(self.fc2.weight)
        I.kaiming_uniform_(self.fc_out.weight)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc_out(x)


class Brain:

    def __init__(self, stateCnt, actionCnt):
        self.stateCnt = stateCnt
        self.actionCnt = actionCnt

        self.model = self._createModel(stateCnt, actionCnt)
        
        self.optimizer = optim.RMSprop(self.model.parameters(), lr=0.00025, eps=1E-7, alpha=0.9, centered=False, weight_decay=0.0)
        self.criterion = nn.MSELoss()

    def _createModel(self, stateCnt, actionCnt):
        model = DQN(stateCnt, actionCnt)
        return model

    def train(self, x, y, epoch=1, verbose=0):
        self.model.train()
        self.optimizer.zero_grad()
        output = self.model(x)
        target = y
        loss = self.criterion(output, target)
        loss.backward()
        self.optimizer.step()

    def predict(self, s):
        self.model.eval()
        return self.model(s)

    def predictOne(self, s):
        self.model.eval()
        return self.model(s)

#-------------------- MEMORY --------------------------
class Memory:   # stored as ( s, a, r, s_ )

    def __init__(self, capacity):
        self.samples = []
        self.capacity = capacity
        
    def __len__(self):
        return len(self.samples)

    def add(self, sample):
        self.samples.append(sample)        

        if len(self) > self.capacity:
            self.samples.pop(0)

    def sample(self, n):
        n = min(n, len(self.samples))
        return random.sample(self.samples, n)

#-------------------- AGENT ---------------------------
MEMORY_CAPACITY = 100000
BATCH_SIZE = 64

GAMMA = 0.99

MAX_EPSILON = 1
MIN_EPSILON = 0.01
LAMBDA = 0.001      # speed of decay

class Agent:
    steps = 0
    epsilon = MAX_EPSILON

    def __init__(self, stateCnt, actionCnt, exhibition_mode=False):
        self.stateCnt = stateCnt
        self.actionCnt = actionCnt

        self.brain = Brain(stateCnt, actionCnt)
        self.memory = Memory(MEMORY_CAPACITY)
        
        self.exhibition_mode = exhibition_mode
        
        if self.exhibition_mode:
            brain_wts = 'cartpole-deeper.torch'
            if os.path.exists(brain_wts):
                self.brain.model.load_state_dict(torch.load('cartpole-deeper.torch'))

        
    def act(self, s):
        max_pred = int(torch.argmax(self.brain.predictOne(s)))
        # Always select the best action
        if self.exhibition_mode:
            return max_pred
        # Espsilon greedy
        if random.random() < self.epsilon:
            return random.randint(0, self.actionCnt-1)
        else:
            return max_pred

    def observe(self, sample):  # in (s, a, r, s_) format
        self.memory.add(sample)        

        # slowly decrease Epsilon based on our eperience
        self.steps += 1
        self.epsilon = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * math.exp(-LAMBDA * self.steps)

    def replay(self):
        if len(self.memory) < BATCH_SIZE:
            return

#         print('Training ...')
        batch = self.memory.sample(BATCH_SIZE)
        batchLen = len(batch)

        no_state = torch.zeros(self.stateCnt)
        
#         print(type(batch[0]))
        states = torch.stack([ o[0] for o in batch ])
        states_ = torch.stack([ (no_state if o[3] is None else o[3]) for o in batch ])
        
        states = states.reshape(batchLen, -1)
        states_ = states_.reshape(batchLen, -1)

        p = self.brain.predict( states )
        p_ = self.brain.predict( states_ )
        
#         print('p', p)
#         print('p_', p_)

        x = torch.zeros((batchLen, self.stateCnt))
        y = torch.zeros((batchLen, self.actionCnt))

        for i in range(0, batchLen):
#             print(i)
            o = batch[i]
            s = o[0]; a = o[1]; r = o[2]; s_ = o[3]

            t = p[i]
#             print('a', a)
#             print('type(a)', type(a))
#             print('t', t)
#             print('t[a]', t[a])
            if s_ is None:
                t[a] = r
            else:
                t[a] = r + GAMMA * float(max(p_[i]))
#                 print(t[a])

            x[i] = s
            y[i] = t
#         print(type(x), type(y))
        x = x.reshape(batchLen, -1)
        y = y.reshape(batchLen, -1)
        self.brain.train(x, y)

#-------------------- ENVIRONMENT ---------------------
class Environment:
    def __init__(self, problem):
        self.problem = problem
        self.env = gym.make(problem)

    def run(self, agent):
        s = self.env.reset()
        s = torch.from_numpy(s).float()
        R = 0

        while True:         
#             self.env.render()

            a = agent.act(s)

            s_, r, done, info = self.env.step(a)
            s_ = torch.from_numpy(s_).float()

            if done: # terminal state
                s_ = None

            # Observe and train, but don't if in exhibition mode
            if not agent.exhibition_mode:
                agent.observe( (s, a, r, s_) )
                agent.replay()

            s = s_
            R += r

            if done:
                break

        return R

#-------------------- MAIN ----------------------------

PROBLEM = 'CartPole-v0'
env = Environment(PROBLEM)

stateCnt  = env.env.observation_space.shape[0]
actionCnt = env.env.action_space.n

# Training mode
agent = Agent(stateCnt, actionCnt, exhibition_mode=False)

# # Exhibition mode
# agent = Agent(stateCnt, actionCnt, exhibition_mode=True)

episode_rewards = []

try:
    while True:
        R = env.run(agent)
        episode_rewards.append(R)
        print("[{:05d}] Total reward: {}".format(len(episode_rewards), R))
        print('n samples: {}'.format(len(agent.memory)))
        
finally:
    if not agent.exhibition_mode:
        torch.save(agent.brain.model.state_dict(), 'cartpole-deeper.torch')
# Out:
# [00001] Total reward: 21.0
# n samples: 21
# [00002] Total reward: 25.0
# n samples: 46
# [00003] Total reward: 14.0
# n samples: 60
# [00004] Total reward: 15.0
# n samples: 75
# [00005] Total reward: 18.0
# n samples: 93
# [00006] Total reward: 11.0
# n samples: 104
# [00007] Total reward: 34.0
# n samples: 138
# [00008] Total reward: 43.0
# n samples: 181
# [00009] Total reward: 13.0
# n samples: 194
# [00010] Total reward: 33.0
# n samples: 227
# [00011] Total reward: 13.0
# n samples: 240
# [00012] Total reward: 20.0
# n samples: 260
# [00013] Total reward: 15.0
# n samples: 275
# [00014] Total reward: 14.0
# n samples: 289
# [00015] Total reward: 11.0
# n samples: 300
# [00016] Total reward: 18.0
# n samples: 318
# [00017] Total reward: 15.0
# n samples: 333
# [00018] Total reward: 10.0
# n samples: 343
# [00019] Total reward: 15.0
# n samples: 358
# [00020] Total reward: 11.0
# n samples: 369
# [00021] Total reward: 16.0
# n samples: 385
# [00022] Total reward: 17.0
# n samples: 402
# [00023] Total reward: 15.0
# n samples: 417
# [00024] Total reward: 11.0
# n samples: 428
# [00025] Total reward: 21.0
# n samples: 449
# [00026] Total reward: 12.0
# n samples: 461
# [00027] Total reward: 11.0
# n samples: 472
# [00028] Total reward: 17.0
# n samples: 489
# [00029] Total reward: 10.0
# n samples: 499
# [00030] Total reward: 14.0
# n samples: 513
# [00031] Total reward: 15.0
# n samples: 528
# [00032] Total reward: 12.0
# n samples: 540
# [00033] Total reward: 11.0
# n samples: 551
# [00034] Total reward: 14.0
# n samples: 565
# [00035] Total reward: 16.0
# n samples: 581
# [00036] Total reward: 11.0
# n samples: 592
# [00037] Total reward: 21.0
# n samples: 613
# [00038] Total reward: 11.0
# n samples: 624
# [00039] Total reward: 14.0
# n samples: 638
# [00040] Total reward: 13.0
# n samples: 651
# [00041] Total reward: 11.0
# n samples: 662
# [00042] Total reward: 9.0
# n samples: 671
# [00043] Total reward: 9.0
# n samples: 680
# [00044] Total reward: 12.0
# n samples: 692
# [00045] Total reward: 14.0
# n samples: 706
# [00046] Total reward: 16.0
# n samples: 722
# [00047] Total reward: 16.0
# n samples: 738
# [00048] Total reward: 13.0
# n samples: 751
# [00049] Total reward: 14.0
# n samples: 765
# [00050] Total reward: 14.0
# n samples: 779
# [00051] Total reward: 9.0
# n samples: 788
# [00052] Total reward: 16.0
# n samples: 804
# [00053] Total reward: 13.0
# n samples: 817
# [00054] Total reward: 12.0
# n samples: 829
# [00055] Total reward: 8.0
# n samples: 837
# [00056] Total reward: 14.0
# n samples: 851
# [00057] Total reward: 13.0
# n samples: 864
# [00058] Total reward: 15.0
# n samples: 879
# [00059] Total reward: 11.0
# n samples: 890
# [00060] Total reward: 15.0
# n samples: 905
# [00061] Total reward: 11.0
# n samples: 916
# [00062] Total reward: 11.0
# n samples: 927
# [00063] Total reward: 10.0
# n samples: 937
# [00064] Total reward: 12.0
# n samples: 949
# [00065] Total reward: 12.0
# n samples: 961
# [00066] Total reward: 15.0
# n samples: 976
# [00067] Total reward: 12.0
# n samples: 988
# [00068] Total reward: 15.0
# n samples: 1003
# [00069] Total reward: 10.0
# n samples: 1013
# [00070] Total reward: 11.0
# n samples: 1024
# [00071] Total reward: 10.0
# n samples: 1034
# [00072] Total reward: 16.0
# n samples: 1050
# [00073] Total reward: 9.0
# n samples: 1059
# [00074] Total reward: 9.0
# n samples: 1068
# [00075] Total reward: 12.0
# n samples: 1080
# [00076] Total reward: 13.0
# n samples: 1093
# [00077] Total reward: 10.0
# n samples: 1103
# [00078] Total reward: 8.0
# n samples: 1111
# [00079] Total reward: 13.0
# n samples: 1124
# [00080] Total reward: 10.0
# n samples: 1134
# [00081] Total reward: 9.0
# n samples: 1143
# [00082] Total reward: 13.0
# n samples: 1156
# [00083] Total reward: 11.0
# n samples: 1167
# [00084] Total reward: 17.0
# n samples: 1184
# [00085] Total reward: 14.0
# n samples: 1198
# [00086] Total reward: 16.0
# n samples: 1214
# [00087] Total reward: 10.0
# n samples: 1224
# [00088] Total reward: 16.0
# n samples: 1240
# [00089] Total reward: 10.0
# n samples: 1250
# [00090] Total reward: 9.0
# n samples: 1259
# [00091] Total reward: 12.0
# n samples: 1271
# [00092] Total reward: 8.0
# n samples: 1279
# [00093] Total reward: 15.0
# n samples: 1294
# [00094] Total reward: 9.0
# n samples: 1303
# [00095] Total reward: 9.0
# n samples: 1312
# [00096] Total reward: 11.0
# n samples: 1323
# [00097] Total reward: 9.0
# n samples: 1332
# [00098] Total reward: 14.0
# n samples: 1346
# [00099] Total reward: 9.0
# n samples: 1355
# [00100] Total reward: 14.0
# n samples: 1369
# [00101] Total reward: 10.0
# n samples: 1379
# [00102] Total reward: 12.0
# n samples: 1391
# [00103] Total reward: 11.0
# n samples: 1402
# [00104] Total reward: 9.0
# n samples: 1411
# [00105] Total reward: 8.0
# n samples: 1419
# [00106] Total reward: 9.0
# n samples: 1428
# [00107] Total reward: 10.0
# n samples: 1438
# [00108] Total reward: 9.0
# n samples: 1447
# [00109] Total reward: 14.0
# n samples: 1461
# [00110] Total reward: 11.0
# n samples: 1472
# [00111] Total reward: 11.0
# n samples: 1483
# [00112] Total reward: 8.0
# n samples: 1491
# [00113] Total reward: 9.0
# n samples: 1500
# [00114] Total reward: 10.0
# n samples: 1510
# [00115] Total reward: 14.0
# n samples: 1524
# [00116] Total reward: 10.0
# n samples: 1534
# [00117] Total reward: 9.0
# n samples: 1543
# [00118] Total reward: 12.0
# n samples: 1555
# [00119] Total reward: 9.0
# n samples: 1564
# [00120] Total reward: 9.0
# n samples: 1573
# [00121] Total reward: 10.0
# n samples: 1583
# [00122] Total reward: 10.0
# n samples: 1593
# [00123] Total reward: 12.0
# n samples: 1605
# [00124] Total reward: 11.0
# n samples: 1616
# [00125] Total reward: 32.0
# n samples: 1648
# [00126] Total reward: 9.0
# n samples: 1657
# [00127] Total reward: 17.0
# n samples: 1674
# [00128] Total reward: 20.0
# n samples: 1694
# [00129] Total reward: 20.0
# n samples: 1714
# [00130] Total reward: 22.0
# n samples: 1736
# [00131] Total reward: 20.0
# n samples: 1756
# [00132] Total reward: 26.0
# n samples: 1782
# [00133] Total reward: 29.0
# n samples: 1811
# [00134] Total reward: 31.0
# n samples: 1842
# [00135] Total reward: 30.0
# n samples: 1872
# [00136] Total reward: 46.0
# n samples: 1918
# [00137] Total reward: 29.0
# n samples: 1947
# [00138] Total reward: 29.0
# n samples: 1976
# [00139] Total reward: 29.0
# n samples: 2005
# [00140] Total reward: 26.0
# n samples: 2031
# [00141] Total reward: 28.0
# n samples: 2059
# [00142] Total reward: 32.0
# n samples: 2091
# [00143] Total reward: 47.0
# n samples: 2138
# [00144] Total reward: 31.0
# n samples: 2169
# [00145] Total reward: 41.0
# n samples: 2210
# [00146] Total reward: 23.0
# n samples: 2233
# [00147] Total reward: 33.0
# n samples: 2266
# [00148] Total reward: 31.0
# n samples: 2297
# [00149] Total reward: 56.0
# n samples: 2353
# [00150] Total reward: 28.0
# n samples: 2381
# [00151] Total reward: 156.0
# n samples: 2537
# [00152] Total reward: 43.0
# n samples: 2580
# [00153] Total reward: 64.0
# n samples: 2644
# [00154] Total reward: 52.0
# n samples: 2696
# [00155] Total reward: 32.0
# n samples: 2728
# [00156] Total reward: 66.0
# n samples: 2794
# [00157] Total reward: 56.0
# n samples: 2850
# [00158] Total reward: 54.0
# n samples: 2904
# [00159] Total reward: 27.0
# n samples: 2931
# [00160] Total reward: 87.0
# n samples: 3018
# [00161] Total reward: 50.0
# n samples: 3068
# [00162] Total reward: 59.0
# n samples: 3127
# [00163] Total reward: 63.0
# n samples: 3190
# [00164] Total reward: 35.0
# n samples: 3225
# [00165] Total reward: 67.0
# n samples: 3292
# [00166] Total reward: 37.0
# n samples: 3329
# [00167] Total reward: 109.0
# n samples: 3438
# [00168] Total reward: 61.0
# n samples: 3499
# [00169] Total reward: 49.0
# n samples: 3548
# [00170] Total reward: 80.0
# n samples: 3628
# [00171] Total reward: 65.0
# n samples: 3693
# [00172] Total reward: 138.0
# n samples: 3831
# [00173] Total reward: 68.0
# n samples: 3899
# [00174] Total reward: 73.0
# n samples: 3972
# [00175] Total reward: 98.0
# n samples: 4070
# [00176] Total reward: 69.0
# n samples: 4139
# [00177] Total reward: 69.0
# n samples: 4208
# [00178] Total reward: 114.0
# n samples: 4322
# [00179] Total reward: 74.0
# n samples: 4396
# [00180] Total reward: 73.0
# n samples: 4469
# [00181] Total reward: 60.0
# n samples: 4529
# [00182] Total reward: 63.0
# n samples: 4592
# [00183] Total reward: 82.0
# n samples: 4674
# [00184] Total reward: 91.0
# n samples: 4765
# [00185] Total reward: 121.0
# n samples: 4886
# [00186] Total reward: 117.0
# n samples: 5003
# [00187] Total reward: 134.0
# n samples: 5137
# [00188] Total reward: 141.0
# n samples: 5278
# [00189] Total reward: 149.0
# n samples: 5427
# [00190] Total reward: 159.0
# n samples: 5586
# [00191] Total reward: 165.0
# n samples: 5751
# [00192] Total reward: 194.0
# n samples: 5945
# [00193] Total reward: 151.0
# n samples: 6096
# [00194] Total reward: 200.0
# n samples: 6296
# [00195] Total reward: 158.0
# n samples: 6454
# [00196] Total reward: 200.0
# n samples: 6654
# [00197] Total reward: 175.0
# n samples: 6829
# [00198] Total reward: 188.0
# n samples: 7017
# [00199] Total reward: 200.0
# n samples: 7217
# [00200] Total reward: 200.0
# n samples: 7417
# [00201] Total reward: 200.0
# n samples: 7617
# [00202] Total reward: 200.0
# n samples: 7817
# [00203] Total reward: 200.0
# n samples: 8017
# [00204] Total reward: 200.0
# n samples: 8217
# [00205] Total reward: 200.0
# n samples: 8417
# [00206] Total reward: 200.0
# n samples: 8617
# [00207] Total reward: 200.0
# n samples: 8817
# [00208] Total reward: 200.0
# n samples: 9017
# [00209] Total reward: 200.0
# n samples: 9217
# [00210] Total reward: 200.0
# n samples: 9417
# [00211] Total reward: 200.0
# n samples: 9617
# [00212] Total reward: 200.0
# n samples: 9817
# [00213] Total reward: 200.0
# n samples: 10017
# [00214] Total reward: 200.0
# n samples: 10217
# [00215] Total reward: 200.0
# n samples: 10417
# [00216] Total reward: 200.0
# n samples: 10617
# [00217] Total reward: 200.0
# n samples: 10817
# [00218] Total reward: 200.0
# n samples: 11017
# [00219] Total reward: 200.0
# n samples: 11217
# [00220] Total reward: 200.0
# n samples: 11417
# [00221] Total reward: 200.0
# n samples: 11617
# [00222] Total reward: 200.0
# n samples: 11817
# [00223] Total reward: 200.0
# n samples: 12017
# [00224] Total reward: 200.0
# n samples: 12217
# [00225] Total reward: 200.0
# n samples: 12417
# [00226] Total reward: 200.0
# n samples: 12617
# [00227] Total reward: 200.0
# n samples: 12817
# [00228] Total reward: 200.0
# n samples: 13017
# [00229] Total reward: 200.0
# n samples: 13217
# [00230] Total reward: 200.0
# n samples: 13417
# [00231] Total reward: 200.0
# n samples: 13617
# [00232] Total reward: 200.0
# n samples: 13817
# [00233] Total reward: 200.0
# n samples: 14017
# [00234] Total reward: 200.0
# n samples: 14217
# [00235] Total reward: 200.0
# n samples: 14417
# [00236] Total reward: 200.0
# n samples: 14617
# [00237] Total reward: 200.0
# n samples: 14817
# [00238] Total reward: 200.0
# n samples: 15017
# [00239] Total reward: 200.0
# n samples: 15217
# [00240] Total reward: 200.0
# n samples: 15417
# [00241] Total reward: 200.0
# n samples: 15617
# [00242] Total reward: 200.0
# n samples: 15817
# [00243] Total reward: 200.0
# n samples: 16017
# [00244] Total reward: 200.0
# n samples: 16217
# [00245] Total reward: 200.0
# n samples: 16417
# [00246] Total reward: 200.0
# n samples: 16617
# [00247] Total reward: 200.0
# n samples: 16817
# [00248] Total reward: 200.0
# n samples: 17017
# [00249] Total reward: 200.0
# n samples: 17217
# [00250] Total reward: 200.0
# n samples: 17417
# [00251] Total reward: 200.0
# n samples: 17617
# [00252] Total reward: 200.0
# n samples: 17817
# [00253] Total reward: 200.0
# n samples: 18017
# [00254] Total reward: 200.0
# n samples: 18217
# [00255] Total reward: 200.0
# n samples: 18417
# [00256] Total reward: 200.0
# n samples: 18617
# [00257] Total reward: 200.0
# n samples: 18817
# [00258] Total reward: 200.0
# n samples: 19017
# [00259] Total reward: 200.0
# n samples: 19217
# [00260] Total reward: 200.0
# n samples: 19417
# [00261] Total reward: 200.0
# n samples: 19617
# [00262] Total reward: 200.0
# n samples: 19817
# [00263] Total reward: 200.0
# n samples: 20017
# [00264] Total reward: 200.0
# n samples: 20217
# [00265] Total reward: 200.0
# n samples: 20417
# [00266] Total reward: 200.0
# n samples: 20617
# [00267] Total reward: 200.0
# n samples: 20817
# [00268] Total reward: 200.0
# n samples: 21017
# [00269] Total reward: 200.0
# n samples: 21217
# [00270] Total reward: 200.0
# n samples: 21417
# [00271] Total reward: 200.0
# n samples: 21617
# [00272] Total reward: 200.0
# n samples: 21817
# [00273] Total reward: 200.0
# n samples: 22017
# [00274] Total reward: 200.0
# n samples: 22217
# [00275] Total reward: 200.0
# n samples: 22417
# [00276] Total reward: 200.0
# n samples: 22617
# [00277] Total reward: 200.0
# n samples: 22817
# [00278] Total reward: 200.0
# n samples: 23017
# [00279] Total reward: 200.0
# n samples: 23217
# [00280] Total reward: 200.0
# n samples: 23417
# [00281] Total reward: 200.0
# n samples: 23617
# [00282] Total reward: 200.0
# n samples: 23817
# [00283] Total reward: 200.0
# n samples: 24017
# [00284] Total reward: 200.0
# n samples: 24217
# [00285] Total reward: 200.0
# n samples: 24417
# [00286] Total reward: 200.0
# n samples: 24617
# [00287] Total reward: 200.0
# n samples: 24817
# [00288] Total reward: 200.0
# n samples: 25017
# [00289] Total reward: 200.0
# n samples: 25217
# [00290] Total reward: 200.0
# n samples: 25417
# [00291] Total reward: 200.0
# n samples: 25617
# [00292] Total reward: 200.0
# n samples: 25817
# [00293] Total reward: 200.0
# n samples: 26017
# [00294] Total reward: 200.0
# n samples: 26217
# [00295] Total reward: 200.0
# n samples: 26417
# [00296] Total reward: 200.0
# n samples: 26617
# [00297] Total reward: 200.0
# n samples: 26817
# [00298] Total reward: 200.0
# n samples: 27017
# [00299] Total reward: 200.0
# n samples: 27217
# [00300] Total reward: 200.0
# n samples: 27417
# [00301] Total reward: 200.0
# n samples: 27617
# [00302] Total reward: 200.0
# n samples: 27817
# [00303] Total reward: 200.0
# n samples: 28017
# [00304] Total reward: 200.0
# n samples: 28217
# [00305] Total reward: 200.0
# n samples: 28417
# [00306] Total reward: 200.0
# n samples: 28617
# [00307] Total reward: 200.0
# n samples: 28817
# [00308] Total reward: 200.0
# n samples: 29017
# [00309] Total reward: 200.0
# n samples: 29217
# [00310] Total reward: 200.0
# n samples: 29417
# [00311] Total reward: 200.0
# n samples: 29617
# [00312] Total reward: 195.0
# n samples: 29812
# [00313] Total reward: 200.0
# n samples: 30012
# [00314] Total reward: 200.0
# n samples: 30212
# [00315] Total reward: 200.0
# n samples: 30412
# [00316] Total reward: 200.0
# n samples: 30612
# [00317] Total reward: 200.0
# n samples: 30812
# [00318] Total reward: 200.0
# n samples: 31012
# [00319] Total reward: 200.0
# n samples: 31212
# [00320] Total reward: 200.0
# n samples: 31412
# [00321] Total reward: 200.0
# n samples: 31612
# [00322] Total reward: 200.0
# n samples: 31812
# [00323] Total reward: 200.0
# n samples: 32012
# [00324] Total reward: 197.0
# n samples: 32209
# [00325] Total reward: 192.0
# n samples: 32401
# [00326] Total reward: 200.0
# n samples: 32601
# [00327] Total reward: 200.0
# n samples: 32801
# [00328] Total reward: 196.0
# n samples: 32997
# [00329] Total reward: 200.0
# n samples: 33197
# [00330] Total reward: 200.0
# n samples: 33397
# [00331] Total reward: 200.0
# n samples: 33597
# [00332] Total reward: 200.0
# n samples: 33797
# [00333] Total reward: 200.0
# n samples: 33997
# [00334] Total reward: 200.0
# n samples: 34197
# [00335] Total reward: 200.0
# n samples: 34397
# [00336] Total reward: 200.0
# n samples: 34597
# [00337] Total reward: 200.0
# n samples: 34797
# [00338] Total reward: 200.0
# n samples: 34997
# [00339] Total reward: 200.0
# n samples: 35197
# [00340] Total reward: 200.0
# n samples: 35397
# [00341] Total reward: 200.0
# n samples: 35597
# [00342] Total reward: 200.0
# n samples: 35797
# [00343] Total reward: 200.0
# n samples: 35997
# [00344] Total reward: 200.0
# n samples: 36197
# [00345] Total reward: 200.0
# n samples: 36397
# [00346] Total reward: 200.0
# n samples: 36597
# [00347] Total reward: 200.0
# n samples: 36797
# [00348] Total reward: 200.0
# n samples: 36997
# [00349] Total reward: 200.0
# n samples: 37197
# [00350] Total reward: 200.0
# n samples: 37397
# [00351] Total reward: 200.0
# n samples: 37597
# [00352] Total reward: 200.0
# n samples: 37797
# [00353] Total reward: 200.0
# n samples: 37997
# [00354] Total reward: 200.0
# n samples: 38197
# [00355] Total reward: 200.0
# n samples: 38397
# [00356] Total reward: 200.0
# n samples: 38597
# [00357] Total reward: 200.0
# n samples: 38797
# [00358] Total reward: 200.0
# n samples: 38997
# [00359] Total reward: 200.0
# n samples: 39197
# [00360] Total reward: 200.0
# n samples: 39397
# [00361] Total reward: 200.0
# n samples: 39597
# [00362] Total reward: 200.0
# n samples: 39797
# [00363] Total reward: 200.0
# n samples: 39997
# [00364] Total reward: 200.0
# n samples: 40197
# [00365] Total reward: 200.0
# n samples: 40397
# [00366] Total reward: 200.0
# n samples: 40597
# [00367] Total reward: 200.0
# n samples: 40797
# [00368] Total reward: 200.0
# n samples: 40997
# [00369] Total reward: 200.0
# n samples: 41197
# [00370] Total reward: 200.0
# n samples: 41397
# [00371] Total reward: 200.0
# n samples: 41597
# [00372] Total reward: 200.0
# n samples: 41797
# [00373] Total reward: 200.0
# n samples: 41997
# [00374] Total reward: 200.0
# n samples: 42197
# [00375] Total reward: 200.0
# n samples: 42397
# [00376] Total reward: 200.0
# n samples: 42597
# [00377] Total reward: 200.0
# n samples: 42797
# [00378] Total reward: 200.0
# n samples: 42997
# [00379] Total reward: 200.0
# n samples: 43197
# [00380] Total reward: 200.0
# n samples: 43397
# [00381] Total reward: 200.0
# n samples: 43597
# [00382] Total reward: 200.0
# n samples: 43797
# [00383] Total reward: 200.0
# n samples: 43997
# [00384] Total reward: 200.0
# n samples: 44197
# [00385] Total reward: 200.0
# n samples: 44397
# [00386] Total reward: 200.0
# n samples: 44597
# [00387] Total reward: 200.0
# n samples: 44797
# [00388] Total reward: 200.0
# n samples: 44997
# [00389] Total reward: 200.0
# n samples: 45197
# [00390] Total reward: 200.0
# n samples: 45397
# [00391] Total reward: 200.0
# n samples: 45597
# [00392] Total reward: 200.0
# n samples: 45797
# [00393] Total reward: 200.0
# n samples: 45997
# [00394] Total reward: 200.0
# n samples: 46197
# [00395] Total reward: 200.0
# n samples: 46397
# [00396] Total reward: 200.0
# n samples: 46597
# [00397] Total reward: 200.0
# n samples: 46797
# [00398] Total reward: 200.0
# n samples: 46997
# [00399] Total reward: 200.0
# n samples: 47197
# [00400] Total reward: 200.0
# n samples: 47397
# [00401] Total reward: 200.0
# n samples: 47597
# [00402] Total reward: 200.0
# n samples: 47797
# [00403] Total reward: 200.0
# n samples: 47997
# [00404] Total reward: 200.0
# n samples: 48197
# [00405] Total reward: 200.0
# n samples: 48397
# [00406] Total reward: 200.0
# n samples: 48597
# [00407] Total reward: 200.0
# n samples: 48797
# [00408] Total reward: 200.0
# n samples: 48997
# [00409] Total reward: 200.0
# n samples: 49197
# [00410] Total reward: 200.0
# n samples: 49397
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-9198913e6d0e> in <module>
#     220 try:
#     221     while True:
# --> 222         R = env.run(agent)
#     223         episode_rewards.append(R)
#     224         print("[{:05d}] Total reward: {}".format(len(episode_rewards), R))
#
# <ipython-input-2-9198913e6d0e> in run(self, agent)
#     192             if not agent.exhibition_mode:
#     193                 agent.observe( (s, a, r, s_) )
# --> 194                 agent.replay()
#     195
#     196             s = s_
#
# <ipython-input-2-9198913e6d0e> in replay(self)
#     157                 t[a] = r
#     158             else:
# --> 159                 t[a] = r + GAMMA * float(max(p_[i]))
#     160 #                 print(t[a])
#     161
#
# KeyboardInterrupt:

# %%
if not agent.exhibition_mode:
    naive_episode_rewards = episode_rewards[:]


fig, ax = plt.subplots()
fig.set_size_inches((16, 4))
ax.plot(naive_episode_rewards, label='Training mode')
ax.legend()

ax.plot(episode_rewards, label='Exhibition mode')
ax.legend()

ax.set_ylabel('Episode reward')
# Out:
# Text(0, 0.5, 'Episode reward')

# %%
# Viz the explored state space
import umap
import numpy as np


reducer = umap.UMAP(verbose=True)
states = np.array([d[0].numpy() for d in agent.memory.samples])
print(states.shape)
embedding = reducer.fit_transform(states)
# Out:
# (49522, 4)
# UMAP(a=None, angular_rp_forest=False, b=None, init='spectral',
#      learning_rate=1.0, local_connectivity=1.0, metric='euclidean',
#      metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
#      n_neighbors=15, negative_sample_rate=5, random_state=None,
#      repulsion_strength=1.0, set_op_mix_ratio=1.0, spread=1.0,
#      target_metric='categorical', target_metric_kwds=None,
#      target_n_neighbors=-1, target_weight=0.5, transform_queue_size=4.0,
#      transform_seed=42, verbose=True)
# Construct fuzzy simplicial set
# Thu Dec 12 22:34:49 2019 Finding Nearest Neighbors
# Thu Dec 12 22:34:49 2019 Building RP forest with 16 trees
# //anaconda3/lib/python3.7/site-packages/numba/compiler.py:588: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../anaconda3/lib/python3.7/site-packages/umap/rp_tree.py", line 135:
# @numba.njit(fastmath=True, nogil=True, parallel=True)
# def euclidean_random_projection_split(data, indices, rng_state):
# ^
#
#   self.func_ir.loc))
# Thu Dec 12 22:34:51 2019 NN descent for 16 iterations
# //anaconda3/lib/python3.7/site-packages/umap/nndescent.py:92: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../anaconda3/lib/python3.7/site-packages/umap/utils.py", line 409:
# @numba.njit(parallel=True)
# def build_candidates(current_graph, n_vertices, n_neighbors, max_candidates, rng_state):
# ^
#
#   current_graph, n_vertices, n_neighbors, max_candidates, rng_state
# //anaconda3/lib/python3.7/site-packages/numba/compiler.py:588: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../anaconda3/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# 	 0  /  16
# 	 1  /  16
# Thu Dec 12 22:34:58 2019 Finished Nearest Neighbor Search
# Thu Dec 12 22:35:01 2019 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Thu Dec 12 22:36:31 2019 Finished embedding

# %%
from matplotlib import pyplot as plt


fig, ax = plt.subplots()
ax.scatter(embedding[:, 0], embedding[:, 1])
fig.set_size_inches((8, 8))
