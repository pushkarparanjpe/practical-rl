# %% [markdown]
# Ref:
# <https://jaromiru.com/2016/10/03/lets-make-a-dqn-implementation/>

# %%
import os

import random, numpy, math, gym
from matplotlib import pyplot as plt


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as I

# %%
#-------------------- BRAIN ---------------------------
class DQN(nn.Module):

    def __init__(self, stateCnt, actionCnt):
        super(DQN, self).__init__()
        self.stateCnt = stateCnt
        self.actionCnt = actionCnt
        self.fc1 = nn.Linear(in_features=stateCnt, out_features=64)
        self.fc2 = nn.Linear(in_features=64, out_features=actionCnt)
#         I.kaiming_uniform_(self.fc1.weight)  # Kaiming seems to be better than Xavier
#         I.kaiming_uniform_(self.fc2.weight)

    def forward(self, x):
#         print(type(x))
        x = F.relu(self.fc1(x))
        return self.fc2(x)


class Brain:

    def __init__(self, stateCnt, actionCnt):
        self.stateCnt = stateCnt
        self.actionCnt = actionCnt

        self.model = self._createModel(stateCnt, actionCnt)
        
        self.optimizer = optim.RMSprop(self.model.parameters(), lr=0.00025, eps=1E-7, alpha=0.9, centered=False, weight_decay=0.0)
        self.criterion = nn.MSELoss()

    def _createModel(self, stateCnt, actionCnt):
        model = DQN(stateCnt, actionCnt)
        return model

    def train(self, x, y, epoch=1, verbose=0):
        self.model.train()
        self.optimizer.zero_grad()
        output = self.model(x)
        target = y
        loss = self.criterion(output, target)
        loss.backward()
        self.optimizer.step()

    def predict(self, s):
        self.model.eval()
        return self.model(s)

    def predictOne(self, s):
        self.model.eval()
        return self.model(s)

#-------------------- MEMORY --------------------------
class Memory:   # stored as ( s, a, r, s_ )

    def __init__(self, capacity):
        self.samples = []
        self.capacity = capacity
        
    def __len__(self):
        return len(self.samples)

    def add(self, sample):
        self.samples.append(sample)        

        if len(self) > self.capacity:
            self.samples.pop(0)

    def sample(self, n):
        n = min(n, len(self.samples))
        return random.sample(self.samples, n)

#-------------------- AGENT ---------------------------
MEMORY_CAPACITY = 100000
BATCH_SIZE = 64

GAMMA = 0.99

MAX_EPSILON = 1
MIN_EPSILON = 0.01
LAMBDA = 0.001      # speed of decay

class Agent:
    steps = 0
    epsilon = MAX_EPSILON

    def __init__(self, stateCnt, actionCnt, exhibition_mode=False):
        self.stateCnt = stateCnt
        self.actionCnt = actionCnt

        self.brain = Brain(stateCnt, actionCnt)
        self.memory = Memory(MEMORY_CAPACITY)
        
        self.exhibition_mode = exhibition_mode
        
        if self.exhibition_mode:
            brain_wts = 'cartpole-basic.torch'
            if os.path.exists(brain_wts):
                self.brain.model.load_state_dict(torch.load('cartpole-basic.torch'))

        
    def act(self, s):
        max_pred = int(torch.argmax(self.brain.predictOne(s)))
        # Always select the best action
        if self.exhibition_mode:
            return max_pred
        # Espsilon greedy
        if random.random() < self.epsilon:
            return random.randint(0, self.actionCnt-1)
        else:
            return max_pred

    def observe(self, sample):  # in (s, a, r, s_) format
        self.memory.add(sample)        

        # slowly decrease Epsilon based on our eperience
        self.steps += 1
        self.epsilon = MIN_EPSILON + (MAX_EPSILON - MIN_EPSILON) * math.exp(-LAMBDA * self.steps)

    def replay(self):
        if len(self.memory) < BATCH_SIZE:
            return

        # Draw a random sample of observations from memory
        batch = self.memory.sample(BATCH_SIZE)
        batchLen = len(batch)

        no_state = torch.zeros(self.stateCnt)
        
        states = torch.stack([ o[0] for o in batch ])
        states_ = torch.stack([ (no_state if o[3] is None else o[3]) for o in batch ])
        
        states = states.reshape(batchLen, -1)
        states_ = states_.reshape(batchLen, -1)

        p = self.brain.predict( states )
        p_ = self.brain.predict( states_ )
        
        x = torch.zeros((batchLen, self.stateCnt))
        y = torch.zeros((batchLen, self.actionCnt))

        for i in range(0, batchLen):
            o = batch[i]
            s = o[0]; a = o[1]; r = o[2]; s_ = o[3]

            # Case A:
            # Episode terminated in the next state (s_)
            if s_ is None:
                # Taking the action 'a' in state 's'
                #   results in transition to state 's_'
                #   In this case 's_' represents a terminal state.
                # Q value of such a transition gets limited to 'r'.
                # We learn that taking action 'a' in state 's' is of lower value.
                # i.e. the DQN adjusts its weights to predict a lower value for
                #      taking action 'a' in state 's'
                p[i][a] = r
            # Case B:
            # Episode continues through to the next state (s_)
            else:
                # Taking action 'a' in state 's'
                #   results in transition to a non-terminal state 's_'
                # Q value of such a transition is higher than just 'r'
                # We learn that taking action 'a' in state 's' is of higher value
                # i.e. the DQN updates its weights to predict a higher value for
                #      taking action 'a' in state 's'
                p[i][a] = r + GAMMA * float(max(p_[i]))

            x[i] = s
            y[i] = p[i]

        self.brain.train(x, y)


#-------------------- ENVIRONMENT ---------------------
class Environment:
    def __init__(self, problem):
        self.problem = problem
        self.env = gym.make(problem)

    def run(self, agent):
        s = self.env.reset()
        s = torch.from_numpy(s).float()
        R = 0

        while True:         
#             self.env.render()

            a = agent.act(s)

            s_, r, done, info = self.env.step(a)
            s_ = torch.from_numpy(s_).float()

            if done: # terminal state
                s_ = None

            # Observe and train, but don't if in exhibition mode
            if not agent.exhibition_mode:
                agent.observe( (s, a, r, s_) )
                agent.replay()

            s = s_
            R += r

            if done:
                break

        return R

#-------------------- MAIN ----------------------------

PROBLEM = 'CartPole-v0'
env = Environment(PROBLEM)

stateCnt  = env.env.observation_space.shape[0]
actionCnt = env.env.action_space.n

# Training mode
agent = Agent(stateCnt, actionCnt, exhibition_mode=False)

# # Exhibition mode
# agent = Agent(stateCnt, actionCnt, exhibition_mode=True)

episode_rewards = []

try:
    while True:
        R = env.run(agent)
        episode_rewards.append(R)
        print("[{:05d}] Total reward: {}".format(len(episode_rewards), R))
        print('n samples: {}'.format(len(agent.memory)))
        
finally:
    if not agent.exhibition_mode:
        torch.save(agent.brain.model.state_dict(), 'cartpole-basic.torch')
# Out:
# [00001] Total reward: 11.0
# n samples: 11
# [00002] Total reward: 18.0
# n samples: 29
# [00003] Total reward: 14.0
# n samples: 43
# [00004] Total reward: 19.0
# n samples: 62
# [00005] Total reward: 13.0
# n samples: 75
# [00006] Total reward: 20.0
# n samples: 95
# [00007] Total reward: 17.0
# n samples: 112
# [00008] Total reward: 13.0
# n samples: 125
# [00009] Total reward: 9.0
# n samples: 134
# [00010] Total reward: 18.0
# n samples: 152
# [00011] Total reward: 28.0
# n samples: 180
# [00012] Total reward: 19.0
# n samples: 199
# [00013] Total reward: 11.0
# n samples: 210
# [00014] Total reward: 16.0
# n samples: 28898
# [00739] Total reward: 200.0
# n samples: 29098
# [00740] Total reward: 182.0
# n samples: 29280
# [00741] Total reward: 200.0
# n samples: 29480
# [00742] Total reward: 132.0
# n samples: 29612
# [00743] Total reward: 170.0
# n samples: 29782
# [00744] Total reward: 200.0
# n samples: 29982
# [00745] Total reward: 198.0
# n samples: 30180
# [00746] Total reward: 182.0
# n samples: 30362
# [00747] Total reward: 200.0
# n samples: 30562
# [00748] Total reward: 200.0
# n samples: 30762
# [00749] Total reward: 200.0
# n samples: 30962
# [00750] Total reward: 200.0
# n samples: 31162
# [00751] Total reward: 200.0
# n samples: 31362
# [00752] Total reward: 200.0
# n samples: 31562
# [00753] Total reward: 170.0
# n samples: 31732
# [00754] Total reward: 164.0
# n samples: 31896
# [00755] Total reward: 200.0
# n samples: 32096
# [00756] Total reward: 154.0
# n samples: 32250
# [00757] Total reward: 200.0
# n samples: 32450
# [00758] Total reward: 200.0
# n samples: 32650
# [00759] Total reward: 200.0
# n samples: 32850
# [00760] Total reward: 200.0
# n samples: 33050
# [00761] Total reward: 200.0
# n samples: 33250
# [00762] Total reward: 200.0
# n samples: 33450
# [00763] Total reward: 200.0
# n samples: 33650
# [00764] Total reward: 200.0
# n samples: 33850
# [00765] Total reward: 200.0
# n samples: 34050
# [00766] Total reward: 200.0
# n samples: 34250
# [00767] Total reward: 200.0
# n samples: 34450
# [00768] Total reward: 200.0
# n samples: 34650
# [00769] Total reward: 200.0
# n samples: 34850
# [00770] Total reward: 200.0
# n samples: 35050
# [00771] Total reward: 200.0
# n samples: 35250
# [00772] Total reward: 200.0
# n samples: 35450
# [00773] Total reward: 200.0
# n samples: 35650
# [00774] Total reward: 200.0
# n samples: 35850
# [00775] Total reward: 200.0
# n samples: 36050
# [00776] Total reward: 200.0
# n samples: 36250
# [00777] Total reward: 174.0
# n samples: 36424
# [00778] Total reward: 200.0
# n samples: 36624
# [00779] Total reward: 199.0
# n samples: 36823
# [00780] Total reward: 200.0
# n samples: 37023
# [00781] Total reward: 200.0
# n samples: 37223
# [00782] Total reward: 200.0
# n samples: 37423
# [00783] Total reward: 200.0
# n samples: 37623
# [00784] Total reward: 200.0
# n samples: 37823
# [00785] Total reward: 200.0
# n samples: 38023
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-21b9f639d3ba> in <module>
#     223 try:
#     224     while True:
# --> 225         R = env.run(agent)
#     226         episode_rewards.append(R)
#     227         print("[{:05d}] Total reward: {}".format(len(episode_rewards), R))
#
# <ipython-input-2-21b9f639d3ba> in run(self, agent)
#     195             if not agent.exhibition_mode:
#     196                 agent.observe( (s, a, r, s_) )
# --> 197                 agent.replay()
#     198
#     199             s = s_
#
# <ipython-input-2-21b9f639d3ba> in replay(self)
#     167             y[i] = p[i]
#     168
# --> 169         self.brain.train(x, y)
#     170
#     171
#
# <ipython-input-2-21b9f639d3ba> in train(self, x, y, epoch, verbose)
#      38         target = y
#      39         loss = self.criterion(output, target)
# ---> 40         loss.backward()
#      41         self.optimizer.step()
#      42
#
# //anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# //anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
if not agent.exhibition_mode:
    naive_episode_rewards = episode_rewards[:]


fig, ax = plt.subplots()
fig.set_size_inches((16, 4))
ax.plot(naive_episode_rewards, label='Training mode')
ax.legend()

ax.plot(episode_rewards, label='Exhibition mode')
ax.legend()

ax.set_ylabel('Episode reward')
# Out:
# Text(0, 0.5, 'Episode reward')

# %%
# Viz the explored state space
import umap
import numpy as np


reducer = umap.UMAP(verbose=True)
states = np.array([d[0].numpy() for d in agent.memory.samples])
print(states.shape)
embedding = reducer.fit_transform(states)
# Out:
# (43899, 4)
# UMAP(a=None, angular_rp_forest=False, b=None, init='spectral',
#      learning_rate=1.0, local_connectivity=1.0, metric='euclidean',
#      metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
#      n_neighbors=15, negative_sample_rate=5, random_state=None,
#      repulsion_strength=1.0, set_op_mix_ratio=1.0, spread=1.0,
#      target_metric='categorical', target_metric_kwds=None,
#      target_n_neighbors=-1, target_weight=0.5, transform_queue_size=4.0,
#      transform_seed=42, verbose=True)
# Construct fuzzy simplicial set
# Thu Dec 12 22:03:11 2019 Finding Nearest Neighbors
# Thu Dec 12 22:03:11 2019 Building RP forest with 15 trees
# //anaconda3/lib/python3.7/site-packages/numba/compiler.py:588: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../anaconda3/lib/python3.7/site-packages/umap/rp_tree.py", line 135:
# @numba.njit(fastmath=True, nogil=True, parallel=True)
# def euclidean_random_projection_split(data, indices, rng_state):
# ^
#
#   self.func_ir.loc))
# Thu Dec 12 22:03:13 2019 NN descent for 15 iterations
# //anaconda3/lib/python3.7/site-packages/numba/compiler.py:588: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../anaconda3/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
# 	 0  /  15
# 	 1  /  15
# Thu Dec 12 22:03:18 2019 Finished Nearest Neighbor Search
# Thu Dec 12 22:03:20 2019 Construct embedding
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Thu Dec 12 22:04:17 2019 Finished embedding

# %%
from matplotlib import pyplot as plt


fig, ax = plt.subplots()
ax.scatter(embedding[:, 0], embedding[:, 1])
fig.set_size_inches((8, 8))
